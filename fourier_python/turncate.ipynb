# %%
import sympy as sym
from sympy import pi

x = sym.symbols('x')
n = 5                   #no of terms
k = 3  

def fourier(function, L, R, n = 3, k = 2):
    ser = sym.fourier_series(function, (x, L, R))
    print(ser.truncate(n))
    sym.plot(ser.truncate(n),(x, k * -pi, k * pi))

L = -pi    #interval start
R = pi     #interval end
square_wave = sym.Piecewise((-1, x < 0),(1, x > 0))
fourier(square_wave, L, R, n, k)
# Out:
# 4*sin(x)/pi + 4*sin(3*x)/(3*pi) + 4*sin(5*x)/(5*pi) + 4*sin(7*x)/(7*pi) + 4*sin(9*x)/(9*pi)
